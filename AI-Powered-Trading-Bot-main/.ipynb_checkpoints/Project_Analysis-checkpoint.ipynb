# %%
# !pip install pandas numpy matplotlib python-dotenv tabulate
# Out:
# Requirement already satisfied: pandas in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: python-dotenv in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Requirement already satisfied: tabulate in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\oğuzhan çelik\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
"""
    CASE 1
"""
# Out:
# '\n    CASE 1\n'

# %%
#Imports
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from Bot import TradingBot
from Patterns.Template.strategy_template import TradingStrategyTemplate
from Patterns.Strategies.GridSearchStrategy import GridSearchStrategy
from Data_Initializer.initializer import DataLoader
from Indicator.calculator import IndicatorCalculator
from Patterns.Observer import LoggingObserver

sys.path.append(os.getcwd())

# %%
# Rules
# Entry Rule
ENTRY_RULES = [
    "RSI_20", "RSI_25", "RSI_30", "RSI_40", 
    "BB_Reversal", "KAMA_ST"
]

# Exit Rule 
# RSI (4) + ST (1) + BB_A (1) + BB_B (7)
BB_B_RATIOS = ["0.10", "0.15", "0.20", "0.25", "0.30", "0.35", "0.40"]
BB_B_EXITS = [f"BB_B_{r}" for r in BB_B_RATIOS]

EXIT_RULES = [
    "RSI_60", "RSI_50", "RSI_45", "RSI_40", 
    "ST_BUY", 
    "BB_A"
] + BB_B_EXITS

ASSETS = ["BTCUSDT", "ETHUSDT"]
TIMEFRAMES = ["1h", "4h", "1d"]
BACKTEST_START_DATE = "1 Jan, 2022"
RESULTS_DF = pd.DataFrame(columns=[
    'Asset', 'Timeframe', 'Entry_Rule', 'Exit_Rule', 
    'Total_PnL_USD', 'Win_Rate', 'Completed_Trades'
])

CASE1_LOG_FILE = "case1_grid_trade_log.txt"

# %%
# Grid-Search Loop & GRID SUMMARY TABLE

grid_logger = LoggingObserver(log_file=CASE1_LOG_FILE)
data_loader = DataLoader()
indicator_calculator = IndicatorCalculator()

for asset in ASSETS:
    for tf in TIMEFRAMES:
        print(f"\n--- Loading Data for {asset} on {tf} ---")

        # Load Data (API)
        historical_data = data_loader.download_crypto_data_interval_backtest(
            api_key=os.getenv("BINANCE_API_KEY"),
            api_secret=os.getenv("BINANCE_API_SECRET"),
            symbol=asset,
            interval=tf,
            check_date=BACKTEST_START_DATE 
        )
        
        # Calculate Indicators (If there is a data extraction error, this will throw an error)
        df_processed = indicator_calculator.calculate_indicators(historical_data)
        
        if len(df_processed) == 0:
            print(f"⚠️ {asset}/{tf} no Valid data, Skipping")
            continue

        # --- Grid Loop ---
        for entry_id in ENTRY_RULES:
            for exit_id in EXIT_RULES:
                
                print(f"Testing: Entry={entry_id}, Exit={exit_id}...")
                
                # Initialize the bot and strategy
                bot = TradingBot(coin_symbol=asset)
                # Stop loss is not needed for Case 1
                grid_strategy = GridSearchStrategy(entry_id, exit_id, stop_loss=0.02)
                bot.set_strategy(grid_strategy)

                bot.register_observer(grid_logger) # register the logger to the bot
                
                # Start Backtest
                final_balance = bot.backtest_trading(
                    initial_balance=10000, 
                    stop_loss=0.02, 
                    df_with_indicators=df_processed,
                    position_size_pct=1.0 # For full balance usage
                )
                
                # Save Results
                pnl = final_balance - 10000 
                trade_stats = bot.get_trade_statistics()

                new_row = {
                    'Asset': asset,
                    'Timeframe': tf,
                    'Entry_Rule': entry_id,
                    'Exit_Rule': exit_id,
                    'Total_PnL_USD': round(pnl, 5),
                    'Final_Balance': round(final_balance, 5),
                    'Win_Rate': trade_stats['win_rate'],
                    'Completed_Trades': trade_stats['completed_trades']
                }
                
                global RESULTS_DF
                RESULTS_DF.loc[len(RESULTS_DF)] = new_row

print("\n--- ✅ Grid-Search Completed ---")
print(RESULTS_DF.sort_values(by='Total_PnL_USD', ascending=False).head())

RESULTS_FILE = "case1_grid_search_results.csv"
RESULTS_DF.to_csv(RESULTS_FILE, index=False)

print(f"\n📊 All Grid Results Saved: {RESULTS_FILE}")
print(f"📝 Detailed Logs Recorded: {CASE1_LOG_FILE}")
# Out:
# [LOG] LoggingObserver initialized - Log target: case1_grid_trade_log.txt
#
# --- Loading Data for BTCUSDT on 1h ---
# ✅ Backtest data loaded: 34342 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 34240 rows available.
# Testing: Entry=RSI_20, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18310963540038686 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15840.96
#    Profit/Loss: $5840.96 (58.41%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.15874081100587664 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13732.79
#    Profit/Loss: $3732.79 (37.33%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1612631180956202 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13951.00
#    Profit/Loss: $3951.00 (39.51%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1581147908634595 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13678.63
#    Profit/Loss: $3678.63 (36.79%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1722042023903004 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14897.52
#    Profit/Loss: $4897.52 (48.98%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16584597535904722 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14347.46
#    Profit/Loss: $4347.46 (43.47%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16165379555268816 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13984.79
#    Profit/Loss: $3984.79 (39.85%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16315844536188603 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14114.96
#    Profit/Loss: $4114.96 (41.15%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1668236141230575 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14432.04
#    Profit/Loss: $4432.04 (44.32%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17092272596664979 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14786.66
#    Profit/Loss: $4786.66 (47.87%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16971490042615706 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14682.17
#    Profit/Loss: $4682.17 (46.82%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16730876572928483 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14474.01
#    Profit/Loss: $4474.01 (44.74%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1708597569514373 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14781.21
#    Profit/Loss: $4781.21 (47.81%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.14536342586883322 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $12575.50
#    Profit/Loss: $2575.50 (25.76%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1513220873161508 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13090.99
#    Profit/Loss: $3090.99 (30.91%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.15165320430917606 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13119.64
#    Profit/Loss: $3119.64 (31.20%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.14915807994491442 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $12903.78
#    Profit/Loss: $2903.78 (29.04%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.14461921605633848 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $12511.12
#    Profit/Loss: $2511.12 (25.11%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16447927797945003 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14229.23
#    Profit/Loss: $4229.23 (42.29%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17617598903323925 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15241.12
#    Profit/Loss: $5241.12 (52.41%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.177493968725974 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15355.14
#    Profit/Loss: $5355.14 (53.55%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1717124399255957 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14854.98
#    Profit/Loss: $4854.98 (48.55%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17607729628105104 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15232.58
#    Profit/Loss: $5232.58 (52.33%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17641831458497792 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15262.08
#    Profit/Loss: $5262.08 (52.62%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17584287254948958 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15212.30
#    Profit/Loss: $5212.30 (52.12%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1774771305386405 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15353.68
#    Profit/Loss: $5353.68 (53.54%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16907641966315837 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14626.93
#    Profit/Loss: $4626.93 (46.27%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18599770477451658 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16090.80
#    Profit/Loss: $6090.80 (60.91%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.19029399136822384 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16462.48
#    Profit/Loss: $6462.48 (64.62%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.185483348367282 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16046.31
#    Profit/Loss: $6046.31 (60.46%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.170901868251268 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14784.85
#    Profit/Loss: $4784.85 (47.85%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.20303805494387198 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $17564.98
#    Profit/Loss: $7564.98 (75.65%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18491639997991058 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15997.26
#    Profit/Loss: $5997.26 (59.97%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18467368144220125 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15976.26
#    Profit/Loss: $5976.26 (59.76%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18224169554290218 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15765.87
#    Profit/Loss: $5765.87 (57.66%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1861897925469242 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16107.42
#    Profit/Loss: $6107.42 (61.07%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18837980604245894 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16296.88
#    Profit/Loss: $6296.88 (62.97%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18918582816151516 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16366.61
#    Profit/Loss: $6366.61 (63.67%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1928100789420822 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16680.15
#    Profit/Loss: $6680.15 (66.80%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.255149477069784 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $22073.18
#    Profit/Loss: $12073.18 (120.73%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.258534662411495 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $22366.03
#    Profit/Loss: $12366.03 (123.66%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.22812807064736762 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $19735.54
#    Profit/Loss: $9735.54 (97.36%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2159329453743264 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18680.53
#    Profit/Loss: $8680.53 (86.81%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2592046744787188 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $22424.00
#    Profit/Loss: $12424.00 (124.24%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2266541243514544 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $19608.02
#    Profit/Loss: $9608.02 (96.08%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1773964460560508 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15346.70
#    Profit/Loss: $5346.70 (53.47%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17800807624443551 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15399.62
#    Profit/Loss: $5399.62 (54.00%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17697667529622937 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15310.39
#    Profit/Loss: $5310.39 (53.10%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17568096133018946 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15198.30
#    Profit/Loss: $5198.30 (51.98%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.17596160660703727 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15222.57
#    Profit/Loss: $5222.57 (52.23%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1730161094998592 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14967.76
#    Profit/Loss: $4967.76 (49.68%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1696669679626052 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14678.02
#    Profit/Loss: $4678.02 (46.78%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2183884258407438 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18892.95
#    Profit/Loss: $8892.95 (88.93%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.22967325916632486 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $19869.21
#    Profit/Loss: $9869.21 (98.69%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.22667826629034282 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $19610.11
#    Profit/Loss: $9610.11 (96.10%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.23034075316857516 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $19926.96
#    Profit/Loss: $9926.96 (99.27%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.21793092485622878 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18853.37
#    Profit/Loss: $8853.37 (88.53%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2043288929551264 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $17676.65
#    Profit/Loss: $7676.65 (76.77%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16479583267253092 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14256.61
#    Profit/Loss: $4256.61 (42.57%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16490599454481128 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14266.14
#    Profit/Loss: $4266.14 (42.66%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.15651600212541097 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13540.32
#    Profit/Loss: $3540.32 (35.40%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.1578346008918271 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13654.39
#    Profit/Loss: $3654.39 (36.54%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.15751224590331717 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13626.51
#    Profit/Loss: $3626.51 (36.27%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.16083077010536687 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13913.59
#    Profit/Loss: $3913.59 (39.14%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34240 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.15772400971735678 adet BTCUSDT $86510.77 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13644.83
#    Profit/Loss: $3644.83 (36.45%)
#
# ======================================================================
#
#
# --- Loading Data for BTCUSDT on 4h ---
# ✅ Backtest data loaded: 8586 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 8484 rows available.
# Testing: Entry=RSI_20, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $17889.28
#    Profit/Loss: $7889.28 (78.89%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $15288.54
#    Profit/Loss: $5288.54 (52.89%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $13716.98
#    Profit/Loss: $3716.98 (37.17%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $13303.28
#    Profit/Loss: $3303.28 (33.03%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $16151.53
#    Profit/Loss: $6151.53 (61.52%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $14814.30
#    Profit/Loss: $4814.30 (48.14%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $11806.42
#    Profit/Loss: $1806.42 (18.06%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $11755.23
#    Profit/Loss: $1755.23 (17.55%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $12290.34
#    Profit/Loss: $2290.34 (22.90%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $12490.45
#    Profit/Loss: $2490.45 (24.90%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $12455.26
#    Profit/Loss: $2455.26 (24.55%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $12550.82
#    Profit/Loss: $2550.82 (25.51%)
#
# ======================================================================
#
# Testing: Entry=RSI_20, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $13058.05
#    Profit/Loss: $3058.05 (30.58%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.2968831064025837 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $25675.64
#    Profit/Loss: $15675.64 (156.76%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_50...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.24301090465664812 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $21016.56
#    Profit/Loss: $11016.56 (110.17%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_45...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.21711516126570976 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18776.99
#    Profit/Loss: $8776.99 (87.77%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=RSI_40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.19144875553222185 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $16557.25
#    Profit/Loss: $6557.25 (65.57%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=ST_BUY...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.30840210558896497 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26671.85
#    Profit/Loss: $16671.85 (166.72%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_A...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.21593724300500963 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18675.12
#    Profit/Loss: $8675.12 (86.75%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $13789.20
#    Profit/Loss: $3789.20 (37.89%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $13604.74
#    Profit/Loss: $3604.74 (36.05%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $14458.78
#    Profit/Loss: $4458.78 (44.59%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $14513.73
#    Profit/Loss: $4513.73 (45.14%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $14183.45
#    Profit/Loss: $4183.45 (41.83%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $15476.01
#    Profit/Loss: $5476.01 (54.76%)
#
# ======================================================================
#
# Testing: Entry=RSI_25, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.18480567288190095 adet BTCUSDT $86484.0 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15982.73
#    Profit/Loss: $5982.73 (59.83%)
#
# ======================================================================
#
# Testing: Entry=RSI_30, Exit=RSI_60...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8484 candles...
# ...
#
# Testing: Entry=RSI_40, Exit=BB_A...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 6.654916496751536 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $18623.45
#    Profit/Loss: $8623.45 (86.23%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 9.497167614327946 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26577.35
#    Profit/Loss: $16577.35 (165.77%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 9.497167614327946 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26577.35
#    Profit/Loss: $16577.35 (165.77%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 9.481840048231513 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26534.46
#    Profit/Loss: $16534.46 (165.34%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 9.356467004364195 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26183.61
#    Profit/Loss: $16183.61 (161.84%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 9.356467004364195 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $26183.61
#    Profit/Loss: $16183.61 (161.84%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 10.05171831236552 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $28129.23
#    Profit/Loss: $18129.23 (181.29%)
#
# ======================================================================
#
# Testing: Entry=RSI_40, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 10.02567385230803 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $28056.35
#    Profit/Loss: $18056.35 (180.56%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_60...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_50...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_45...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=RSI_40...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=ST_BUY...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_A...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=BB_Reversal, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_60...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.1204955501584495 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11531.00
#    Profit/Loss: $1531.00 (15.31%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_50...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 5.068709044668103 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14184.53
#    Profit/Loss: $4184.53 (41.85%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_45...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.900938936672954 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $13715.03
#    Profit/Loss: $3715.03 (37.15%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=RSI_40...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 5.152160315797696 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $14418.06
#    Profit/Loss: $4418.06 (44.18%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=ST_BUY...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.1204955501584495 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11531.00
#    Profit/Loss: $1531.00 (15.31%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_A...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 5.3768897511787115 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $15046.96
#    Profit/Loss: $5046.96 (50.47%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.10...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.3767516594888995 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $12248.12
#    Profit/Loss: $2248.12 (22.48%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.15...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.2087384262186545 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11777.94
#    Profit/Loss: $1777.94 (17.78%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.20...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.068934495699711 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11386.71
#    Profit/Loss: $1386.71 (13.87%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.25...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.194271748990268 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11737.46
#    Profit/Loss: $1737.46 (17.37%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.30...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.194271748990268 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11737.46
#    Profit/Loss: $1737.46 (17.37%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.35...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.221967651197293 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11814.97
#    Profit/Loss: $1814.97 (18.15%)
#
# ======================================================================
#
# Testing: Entry=KAMA_ST, Exit=BB_B_0.40...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 4.221967651197293 adet ETHUSDT $2798.45 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11814.97
#    Profit/Loss: $1814.97 (18.15%)
#
# ======================================================================
#
#
# --- ✅ Grid-Search Completed ---
#        Asset Timeframe Entry_Rule  Exit_Rule  Total_PnL_USD  Win_Rate  \
# 337  ETHUSDT        4h     RSI_25  BB_B_0.40    20276.86171     100.0
# 336  ETHUSDT        4h     RSI_25  BB_B_0.35    20064.69573     100.0
# 335  ETHUSDT        4h     RSI_25  BB_B_0.30    20059.91599     100.0
# 334  ETHUSDT        4h     RSI_25  BB_B_0.25    19969.59126     100.0
# 332  ETHUSDT        4h     RSI_25  BB_B_0.15    19629.90727     100.0
#
#      Completed_Trades
# 337                26
# 336                27
# 335                28
# 334                29
# 332                30
#
# 📊 All Grid Results Saved: case1_grid_search_results.csv
# 📝 Detailed Logs Recorded: case1_grid_trade_log.txt

# %%
try:
    df = pd.read_csv("case1_grid_search_results.csv")

    df_sorted = df.sort_values(
        by=['Total_PnL_USD', 'Timeframe'],
        ascending=[False, True]
    )
    df_btc = df_sorted[df_sorted['Asset'] == 'BTCUSDT']
    df_eth = df_sorted[df_sorted['Asset'] == 'ETHUSDT']
    print("--- BTCUSDT Grid Search Results (Sorted by PnL) ---")
    print(df_btc.head(20).to_markdown(index=False))
    print("\n--- ETHUSDT Grid Search Results (Sorted by PnL) ---")
    print(df_eth.head(20).to_markdown(index=False))

except FileNotFoundError:
    print("HATA: 'case1_grid_search_results.csv' file was not found. Please check the name and path of the file.")
# Out:
# --- BTCUSDT Grid Search Results (Sorted by PnL) ---
# | Asset   | Timeframe   | Entry_Rule   | Exit_Rule   |   Total_PnL_USD |   Win_Rate |   Completed_Trades |
# |:--------|:------------|:-------------|:------------|----------------:|-----------:|-------------------:|
# | BTCUSDT | 4h          | RSI_25       | ST_BUY      |        16671.8  |        100 |                 22 |
# | BTCUSDT | 4h          | RSI_25       | RSI_60      |        15675.6  |        100 |                 20 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.15   |        13861.8  |        100 |                 69 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.20   |        13861.8  |        100 |                 69 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.10   |        13800.5  |        100 |                 69 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.25   |        13564.1  |        100 |                 67 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.35   |        13233    |        100 |                 64 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.40   |        12703.5  |        100 |                 59 |
# | BTCUSDT | 1h          | RSI_40       | ST_BUY      |        12424    |        100 |                 92 |
# | BTCUSDT | 4h          | KAMA_ST      | BB_B_0.30   |        12370.1  |        100 |                 62 |
# | BTCUSDT | 1h          | RSI_40       | RSI_50      |        12366    |        100 |                125 |
# | BTCUSDT | 1h          | RSI_40       | RSI_60      |        12073.2  |        100 |                 80 |
# | BTCUSDT | 4h          | RSI_25       | RSI_50      |        11016.6  |        100 |                 22 |
# | BTCUSDT | 1d          | RSI_40       | ST_BUY      |        10810.6  |        100 |                 15 |
# | BTCUSDT | 1h          | KAMA_ST      | RSI_40      |         9926.96 |        100 |                282 |
# | BTCUSDT | 1h          | KAMA_ST      | RSI_50      |         9869.21 |        100 |                171 |
# | BTCUSDT | 1d          | KAMA_ST      | ST_BUY      |         9785.45 |        100 |                 11 |
# | BTCUSDT | 1h          | RSI_40       | RSI_45      |         9735.54 |        100 |                155 |
# | BTCUSDT | 1h          | KAMA_ST      | RSI_45      |         9610.11 |        100 |                236 |
# | BTCUSDT | 1h          | RSI_40       | BB_A        |         9608.02 |        100 |                114 |
#
# --- ETHUSDT Grid Search Results (Sorted by PnL) ---
# | Asset   | Timeframe   | Entry_Rule   | Exit_Rule   |   Total_PnL_USD |   Win_Rate |   Completed_Trades |
# |:--------|:------------|:-------------|:------------|----------------:|-----------:|-------------------:|
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.40   |         20276.9 |        100 |                 26 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.35   |         20064.7 |        100 |                 27 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.30   |         20059.9 |        100 |                 28 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.25   |         19969.6 |        100 |                 29 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.15   |         19629.9 |        100 |                 30 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.20   |         19433.9 |        100 |                 29 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.35   |         18129.2 |        100 |                 21 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.40   |         18056.3 |        100 |                 21 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.10   |         17455.1 |        100 |                 31 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.10   |         16577.3 |        100 |                 23 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.15   |         16577.3 |        100 |                 23 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.20   |         16534.5 |        100 |                 22 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.25   |         16183.6 |        100 |                 21 |
# | ETHUSDT | 1d          | RSI_40       | BB_B_0.30   |         16183.6 |        100 |                 21 |
# | ETHUSDT | 4h          | RSI_30       | RSI_50      |         12181.2 |        100 |                 30 |
# | ETHUSDT | 1d          | RSI_25       | RSI_60      |         12084.5 |        100 |                  4 |
# | ETHUSDT | 4h          | RSI_20       | BB_B_0.40   |         11833.6 |        100 |                 19 |
# | ETHUSDT | 4h          | RSI_25       | RSI_50      |         11460.1 |        100 |                 23 |
# | ETHUSDT | 4h          | RSI_20       | BB_B_0.35   |         11072.3 |        100 |                 19 |
# | ETHUSDT | 4h          | RSI_25       | RSI_45      |         11039.9 |        100 |                 24 |

# %%
# BEST COMBINATION TRADE LIST

#Uploading the Detailed Log File
LOG_FILE = "case1_grid_trade_log.txt"
try:
    with open(LOG_FILE, 'r', encoding='utf-8', errors='ignore') as f:
        log_lines = f.readlines()
except FileNotFoundError:
    print(f"❌ ERROR: {LOG_FILE} not found. Transaction details cannot be displayed..")
    log_lines = []

# Chooses the best combo based on the asset
def get_best_combo_trades(asset_symbol: str, results_df: pd.DataFrame, log_lines: list) -> tuple:
    # Filter asset and sort by PnL
    asset_results = results_df[results_df['Asset'] == asset_symbol]
    if asset_results.empty:
        return None, pd.DataFrame()
        
    best_combo = asset_results.sort_values(by='Total_PnL_USD', ascending=False).iloc[0]
    best_entry = best_combo['Entry_Rule']
    best_exit = best_combo['Exit_Rule']
    
   # Filter the logs and convert them into tables
    trade_list = []
    entry_info = {} # Keeps open position information

    for line in log_lines:
        if f"Strategy: GridSearchStrategy" in line and f"Bought {asset_symbol}" in line or f"Sold {asset_symbol}" in line:
            parts = line.split(',')
            timestamp_str = str(parts[1].split(': ')[1])
            if "Sold" in line and f"Trigger: {best_exit}" in line:
                try:
                    sell_price = float(parts[2].split(': ')[1])
                    pnl_str = [p for p in parts if 'PnL:' in p][0]
                    pnl_usd = float(pnl_str.split(': $')[1].split(' (')[0])
                except (IndexError, ValueError):
                    continue
                if entry_info.get('strategy') == f"GridSearchStrategy (Entry: {best_entry})":
                    duration = pd.to_datetime(timestamp_str) - entry_info['date']
                    trade_list.append({
                        'Action': 'SELL',
                        'Date': timestamp_str,
                        'Price': round(sell_price, 2),
                        'PnL_USD': round(pnl_usd, 2),
                        'PnL_%': round((sell_price / entry_info['price'] - 1) * 100, 2),
                        'Duration': str(duration),
                        'Entry_Rule': best_entry,
                        'Exit_Rule': best_exit
                    })
                    entry_info = {} # Close the position

            elif "Bought" in line and f"Trigger: {best_entry}" in line and entry_info == {}:
                try:
                    entry_price = float(parts[2].split(': ')[1])
                    position_size = float(parts[4].split(': ')[1])
                except (IndexError, ValueError):
                    continue
                entry_info = {
                    'date': pd.to_datetime(timestamp_str),
                    'price': entry_price,
                    'position': position_size,
                    'strategy': f"GridSearchStrategy (Entry: {best_entry})"
                }
                
    return best_combo, pd.DataFrame(trade_list)

#Calculate Results for BTCUSDT (Bitcoin)
btc_combo, btc_trade_list = get_best_combo_trades('BTCUSDT', RESULTS_DF, log_lines)

if btc_combo is not None:
    print("\n" + "="*80)
    print("🏆 BTCUSDT BEST COMBINATION CHOSEN:")
    print(f"   Time Frame: {btc_combo['Timeframe']}, Entry Rule: {btc_combo['Entry_Rule']}, Exit Rule: {btc_combo['Exit_Rule']}")
    print(f"   Total Profit/Loss: ${btc_combo['Total_PnL_USD']:.2f}")
    
    print("\n--- BTCUSDT BEST COMBINATION TRADE DETAILS (First 10 Transactions) ---")
    if not btc_trade_list.empty:
        print(btc_trade_list.head(10).to_markdown(index=False))
    else:
        print("No completed transactions were found for BTCUSDT in the log file.")
else:
    print("\nBTCUSDT data not found in Grid Results table.")


# Calculate Results for ETHUSDT (Ethereum)
eth_combo, eth_trade_list = get_best_combo_trades('ETHUSDT', RESULTS_DF, log_lines)

if eth_combo is not None:
    print("\n" + "="*80)
    print("🏆 ETHUSDT BEST COMBINATION CHOSEN:")
    print(f"   Time Frame: {eth_combo['Timeframe']}, Entry Rule: {eth_combo['Entry_Rule']}, Exit Rule: {eth_combo['Exit_Rule']}")
    print(f"   Total Profit/Loss: ${eth_combo['Total_PnL_USD']:.2f}")

    print("\n--- ETHUSDT BEST COMBINATION TRADE DETAILS (First 10 Transactions) ---")
    if not eth_trade_list.empty:
        print(eth_trade_list.head(10).to_markdown(index=False))
    else:
        print("No completed transactions for ETHUSDT were found in the log file.")
else:
    print("\nETHUSDT data was not found in the Grid Results table.")
# Out:
# ================================================================================
# 🏆 BTCUSDT BEST COMBINATION CHOSEN:
#    Time Frame: 4h, Entry Rule: RSI_25, Exit Rule: ST_BUY
#    Total Profit/Loss: $16671.85
#
# --- BTCUSDT BEST COMBINATION TRADE DETAILS (First 10 Transactions) ---
# | Action   | Date                |   Price |   PnL_USD |   PnL_% | Duration          | Entry_Rule   | Exit_Rule   |
# |:---------|:--------------------|--------:|----------:|--------:|:------------------|:-------------|:------------|
# | SELL     | 2022-01-13 17:00:00 | 44154.5 |     42.65 |    0.43 | 7 days 18:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2022-01-31 20:00:00 | 38473   |      1.93 |    0.02 | 10 days 14:00:00  | RSI_25       | ST_BUY      |
# | SELL     | 2022-03-01 01:00:00 | 43026.4 |    263.57 |    2.62 | 11 days 08:00:00  | RSI_25       | ST_BUY      |
# | SELL     | 2022-03-09 06:00:00 | 41217.7 |    132.58 |    1.29 | 4 days 12:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2022-03-14 10:00:00 | 39078.9 |    375.88 |    3.6  | 0 days 09:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2022-04-01 17:00:00 | 46128.9 |    290.17 |    2.68 | 0 days 13:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2023-12-06 01:00:00 | 44285.4 |     30.05 |    0.27 | 608 days 09:00:00 | RSI_25       | ST_BUY      |
# | SELL     | 2023-12-13 20:00:00 | 42118.6 |     43.96 |    0.39 | 2 days 15:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2023-12-18 23:00:00 | 41971.1 |    269.84 |    2.41 | 0 days 19:00:00   | RSI_25       | ST_BUY      |
# | SELL     | 2023-12-25 17:00:00 | 43674.1 |    185.65 |    1.62 | 0 days 16:00:00   | RSI_25       | ST_BUY      |
#
# ================================================================================
# 🏆 ETHUSDT BEST COMBINATION CHOSEN:
#    Time Frame: 4h, Entry Rule: RSI_25, Exit Rule: BB_B_0.40
#    Total Profit/Loss: $20276.86
#
# --- ETHUSDT BEST COMBINATION TRADE DETAILS (First 10 Transactions) ---
# | Action   | Date                |   Price |   PnL_USD |   PnL_% | Duration          | Entry_Rule   | Exit_Rule   |
# |:---------|:--------------------|--------:|----------:|--------:|:------------------|:-------------|:------------|
# | SELL     | 2024-03-05 19:00:00 | 3688.07 |    263.28 |    2.63 | 789 days 20:00:00 | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-03-19 15:00:00 | 3295.93 |    171.5  |    1.67 | 0 days 04:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-04-07 20:00:00 | 3386.59 |     63.58 |    0.61 | 5 days 14:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-05-21 22:00:00 | 3712.27 |   1221.39 |   11.63 | 39 days 02:00:00  | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-06-08 04:00:00 | 3690.94 |     35.77 |    0.31 | 0 days 07:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-11-28 13:00:00 | 3603.26 |      2.15 |    0.02 | 170 days 08:00:00 | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-12-19 06:00:00 | 3668.9  |    136.48 |    1.16 | 0 days 04:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-12-25 16:00:00 | 3482.57 |      9.33 |    0.08 | 5 days 20:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2024-12-26 19:00:00 | 3356.97 |     60.48 |    0.51 | 0 days 02:00:00   | RSI_25       | BB_B_0.40   |
# | SELL     | 2025-07-18 18:00:00 | 3563.68 |    349.11 |    2.92 | 192 days 00:00:00 | RSI_25       | BB_B_0.40   |

# %%
# CHARTS

# Plots price, indicators and buy/sell signals for the specified best combination
def plot_best_strategy(combo, trade_list):
    if combo is None or trade_list.empty:
        print(f"⚠️ {combo['Asset']} no completed transaction details found. Graph cannot be drawn.")
        return

    asset = combo['Asset']
    tf = combo['Timeframe']
    buy_dates, sell_dates = pd.Index([]), pd.Index([])
    buy_prices, sell_prices = pd.Series(), pd.Series()

    print(f"\n--- Chart data loading: {asset} ({tf}) ---")
    try:
        # Load and Process the Best Dataset
        historical_data = data_loader.download_crypto_data_interval_backtest(
            api_key=os.getenv("BINANCE_API_KEY"),
            api_secret=os.getenv("BINANCE_API_SECRET"),
            symbol=asset,
            interval=tf,
            check_date="100 days ago UTC" # A shorter period can be selected for the chart
        )
        df_chart = indicator_calculator.calculate_indicators(historical_data)
        df_chart.index = pd.to_datetime(df_chart.index)

    except Exception as e:
        print(f"❌ ERROR: {asset} An error occurred while loading/calculating data: {e}")
        return
    
    buy_signals = trade_list[trade_list['Action'] == 'BUY']
    sell_signals = trade_list[trade_list['Action'] == 'SELL'] 
    
    # Convert signal dates to DatetimeIndex
    buy_dates_raw = pd.Index(pd.to_datetime(buy_signals['Date']).dt.floor('S'))
    sell_dates_raw = pd.Index(pd.to_datetime(sell_signals['Date']).dt.floor('S'))
    # Select existing dates in df_chart.index:
    valid_buy_dates = buy_dates_raw.intersection(df_chart.index)
    valid_sell_dates = sell_dates_raw.intersection(df_chart.index)
    
    # Finding signal prices on DatetimeIndex
    buy_prices = df_chart.loc[valid_buy_dates, 'Close'].dropna()
    sell_prices = df_chart.loc[valid_sell_dates, 'Close'].dropna()

    # Creating Graphics
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(18, 12), sharex=True, gridspec_kw={'height_ratios': [3, 1]})

    # ----------------- TOP GRAPH (Price, BB, SuperTrend) -----------------
    ax1.plot(df_chart.index, df_chart['Close'], label='Exit Price', color='black', alpha=0.6)

    # Bollinger Bands
    ax1.plot(df_chart.index, df_chart['BB_upper'], label='BB Upper Band', color='blue', linestyle='--')
    ax1.plot(df_chart.index, df_chart['BB_middle'], label='BB Mid Band (SMA)', color='gray', linestyle='--')
    ax1.plot(df_chart.index, df_chart['BB_lower'], label='BB Lower Band', color='blue', linestyle='--')

    # SuperTrend Direction Display
    ax1.scatter(df_chart.index, 
                df_chart['Close'], 
                c=df_chart['ST_DIR'].apply(lambda x: 'green' if x == 1 else 'red'),
                marker='.', s=10, alpha=0.3, label='SuperTrend Direction')

    # Buy/Sell Signals (▲ Buy, × Sell)
    if not buy_prices.empty:
        ax1.scatter(valid_buy_dates, buy_prices, label='Buy (Entry)', marker='^', color='green', s=200, zorder=10)
    if not sell_prices.empty:
        ax1.scatter(valid_sell_dates, sell_prices, label='Sell (Exit)', marker='x', color='red', s=200, linewidths=2, zorder=10)

    ax1.set_title(f'Test Case 1: {asset} ({tf}) - Best Combination', fontsize=16)
    ax1.set_ylabel('Price (USD)')
    ax1.legend(loc='upper left')
    ax1.grid(True, alpha=0.5)

    # ----------------- BOTTOM GRAPH (RSI) -----------------
    ax2.plot(df_chart.index, df_chart['rsi'], label='RSI (14)', color='purple')

    # RSI Overbought/Oversold Levels
    ax2.axhline(70, color='red', linestyle='--', alpha=0.7, label='Over Bought (70)')
    ax2.axhline(30, color='green', linestyle='--', alpha=0.7, label='Over Sold (30)')
    ax2.fill_between(df_chart.index, 70, df_chart['rsi'], where=(df_chart['rsi'] > 70), color='red', alpha=0.1)
    ax2.fill_between(df_chart.index, 30, df_chart['rsi'], where=(df_chart['rsi'] < 30), color='green', alpha=0.1)

    ax2.set_ylabel('RSI Value')
    ax2.set_xlabel('Date')
    ax2.set_ylim(0, 100)
    ax2.grid(True, alpha=0.5)
    ax2.legend(loc='upper left')

    plt.tight_layout()
    plt.show()
    print(f"✅ {asset} chart created successfully.")

# BTCUSDT Graph
plot_best_strategy(btc_combo, btc_trade_list)

# ETHUSDT Graph
plot_best_strategy(eth_combo, eth_trade_list)
# Out:
# --- Grafik verisi çekiliyor: BTCUSDT (4h) ---
# ✅ Backtest data loaded: 600 rows from 100 days ago UTC
# ✅ Indicators calculated successfully. 498 rows available.
# C:\Users\mst29\AppData\Local\Temp\ipykernel_24276\2529254252.py:35: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   buy_dates_raw = pd.Index(pd.to_datetime(buy_signals['Date']).dt.floor('S'))
# C:\Users\mst29\AppData\Local\Temp\ipykernel_24276\2529254252.py:36: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   sell_dates_raw = pd.Index(pd.to_datetime(sell_signals['Date']).dt.floor('S'))
# ✅ BTCUSDT chart created successfully.
#
# --- Grafik verisi çekiliyor: ETHUSDT (4h) ---
# ✅ Backtest data loaded: 600 rows from 100 days ago UTC
# ✅ Indicators calculated successfully. 498 rows available.
# C:\Users\mst29\AppData\Local\Temp\ipykernel_24276\2529254252.py:35: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   buy_dates_raw = pd.Index(pd.to_datetime(buy_signals['Date']).dt.floor('S'))
# C:\Users\mst29\AppData\Local\Temp\ipykernel_24276\2529254252.py:36: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   sell_dates_raw = pd.Index(pd.to_datetime(sell_signals['Date']).dt.floor('S'))
# ✅ ETHUSDT chart created successfully.

# %%
"""
    CASE 2
"""
# Out:
# '\n    CASE 2\n'

# %%
# Imports
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv
import matplotlib.pyplot as plt

from Bot import TradingBot
from Indicator.calculator import IndicatorCalculator
from Data_Initializer.initializer import DataLoader
from Patterns.Strategies.IchimokuCustomStrategy import IchimokuCustomStrategy
from Patterns.Observer import LoggingObserver

# %%
# Rules
ASSETS = ["BTCUSDT", "ETHUSDT"]
TIMEFRAMES = ["1h", "4h", "1d"] 
BACKTEST_START_DATE = "1 Jan, 2022"

# Note: Table to be compared with Case 1 RESULTS_DF
CUSTOM_RESULTS_DF = pd.DataFrame(columns=[
    'Asset', 'Timeframe', 'Entry_Rule', 'Exit_Rule', 
    'Total_PnL_USD', 'Win_Rate', 'Completed_Trades'
])

CASE2_LOG_FILE = "case2_ichimoku_log.txt"

# %%
# Ichimoku & Custom Rule loop & PERFORMANCE TABLES

ichimoku_logger = LoggingObserver(log_file=CASE2_LOG_FILE)
data_loader = DataLoader()
indicator_calculator = IndicatorCalculator()

for asset in ASSETS:
    for tf in TIMEFRAMES:
        
        print(f"\n--- 📥 Loading data for: {asset} / {tf} ---")
        
        # Load Data (API)
        try:
            historical_data = data_loader.download_crypto_data_interval_backtest(
                api_key=os.getenv("BINANCE_API_KEY"),
                api_secret=os.getenv("BINANCE_API_SECRET"),
                symbol=asset,
                interval=tf,
                check_date=BACKTEST_START_DATE 
            )
            df_processed = indicator_calculator.calculate_indicators(historical_data)
            if df_processed.empty:
                print(f"⚠️ {asset}/{tf} No valid data found. Skipping.")
                continue
        except Exception as e:
            print(f"❌ERROR: Data extraction/processing error ({asset}/{tf}): {e}. Skipping.")
            continue

        print(f"   Testing: Ichimoku Custom Rule...")
        #Adjust Strategy (One Rule)
        current_strategy = IchimokuCustomStrategy(stop_loss=0.02)
        
        bot = TradingBot(coin_symbol=asset)
        bot.set_strategy(current_strategy)
        bot.register_observer(ichimoku_logger) # register the logger
        
        # Run Backtest
        final_balance = bot.backtest_trading(
            initial_balance=10000,
            stop_loss=0.02,
            df_with_indicators=df_processed,
            position_size_pct=1.0
        )

        # Save Results
        pnl = final_balance - 10000
        stats = bot.get_trade_statistics()

        new_row = {
            'Asset': asset,
            'Timeframe': tf,
            # Return values of IchimokuCustomStrategy
            'Entry_Rule': 'IchimokuEntry', 
            'Exit_Rule': 'CustomExit/SL',
            'Total_PnL_USD': round(pnl, 2),
            'Final_Balance': round(final_balance, 5),
            'Win_Rate': round(stats['win_rate'], 4),
            'Completed_Trades': stats['completed_trades']
        }

        CUSTOM_RESULTS_DF.loc[len(CUSTOM_RESULTS_DF)] = new_row

CUSTOM_RESULTS_FILE = "case2_ichimoku_results.csv"
CUSTOM_RESULTS_DF.to_csv(CUSTOM_RESULTS_FILE, index=False)
print("\n" + "="*70)
print("✅ TEST CASE 2: ICHIMOKU CUSTOM RULE RESULT SUMMARY")
print(CUSTOM_RESULTS_DF.to_markdown(index=False))
print("="*70)
print(f"📊 All Grid Results Saved: {CUSTOM_RESULTS_FILE}")
print(f"📝 Detailed Logs Recorded: {CASE2_LOG_FILE}")
# Out:
# [LOG] LoggingObserver initialized - Log target: case2_ichimoku_log.txt
#
# --- 📥 Loading data for: BTCUSDT / 1h ---
# ✅ Backtest data loaded: 34336 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 34234 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34234 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# --- 📥 Loading data for: BTCUSDT / 4h ---
# ✅ Backtest data loaded: 8585 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 8483 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8483 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# --- 📥 Loading data for: BTCUSDT / 1d ---
# ✅ Backtest data loaded: 1431 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 1329 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# --- 📥 Loading data for: ETHUSDT / 1h ---
# ✅ Backtest data loaded: 34336 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 34234 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 34234 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# --- 📥 Loading data for: ETHUSDT / 4h ---
# ✅ Backtest data loaded: 8585 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 8483 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 8483 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# --- 📥 Loading data for: ETHUSDT / 1d ---
# ✅ Backtest data loaded: 1431 rows from 1 Jan, 2022
# ✅ Indicators calculated successfully. 1329 rows available.
#    Testing: Ichimoku Custom Rule...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 1329 candles...
#
# 📊 Backtest Complete!
#    Final Balance: $10000.00
#    Profit/Loss: $0.00 (0.00%)
#
# ======================================================================
#
#
# ======================================================================
# ✅ TEST CASE 2: ICHIMOKU CUSTOM RULE RESULT SUMMARY
# | Asset   | Timeframe   | Entry_Rule    | Exit_Rule     |   Total_PnL_USD |   Win_Rate |   Completed_Trades |
# |:--------|:------------|:--------------|:--------------|----------------:|-----------:|-------------------:|
# | BTCUSDT | 1h          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# | BTCUSDT | 4h          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# | BTCUSDT | 1d          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# | ETHUSDT | 1h          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# | ETHUSDT | 4h          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# | ETHUSDT | 1d          | IchimokuEntry | CustomExit/SL |               0 |          0 |                  0 |
# ======================================================================
# 📊 All Grid Results Saved: case2_ichimoku_results.csv
# 📝 Detailed Logs Recorded: case2_ichimoku_log.txt

# %%
# BEST TF OF ICHIMOKU
TARGET_RESULTS_BTC = CUSTOM_RESULTS_DF[CUSTOM_RESULTS_DF['Asset'] == "BTCUSDT"]
TARGET_RESULTS_ETH = CUSTOM_RESULTS_DF[CUSTOM_RESULTS_DF['Asset'] == "ETHUSDT"]

best_combo_btc = TARGET_RESULTS_BTC.sort_values(by='Total_PnL_USD', ascending=False).iloc[0]
best_combo_eth = TARGET_RESULTS_ETH.sort_values(by='Total_PnL_USD', ascending=False).iloc[0]

print("\n" + "="*80)
print("🏆 BTCUSDT BEST TF CHOSEN:")
print(f"   Time Frame: {best_combo_btc['Timeframe']}, Entry Rule: {best_combo_btc['Entry_Rule']}, Exit Rule: {best_combo_btc['Exit_Rule']}")
print(f"   Total Profit/Loss: ${best_combo_btc['Total_PnL_USD']:.2f}")

print("\n" + "="*80)
print("🏆 ETHUSDT BEST TF CHOSEN:")
print(f"   Time Frame: {best_combo_eth['Timeframe']}, Entry Rule: {best_combo_eth['Entry_Rule']}, Exit Rule: {best_combo_eth['Exit_Rule']}")
print(f"   Total Profit/Loss: ${best_combo_eth['Total_PnL_USD']:.2f}")
# Out:
# ================================================================================
# 🏆 BTCUSDT BEST TF CHOSEN:
#    Time Frame: 1h, Entry Rule: IchimokuEntry, Exit Rule: CustomExit/SL
#    Toplam Kâr/Zarar: $0.00
#
# ================================================================================
# 🏆 ETHUSDT BEST TF CHOSEN:
#    Time Frame: 1h, Entry Rule: IchimokuEntry, Exit Rule: CustomExit/SL
#    Toplam Kâr/Zarar: $0.00

# %%
#CHARTS

def plot_ichimoku_with_signal(ASSET_TO_PLOT: str, tf: str):
    try:
        historical_data = data_loader.download_crypto_data_interval_backtest(
            api_key=os.getenv("BINANCE_API_KEY"),
            api_secret=os.getenv("BINANCE_API_SECRET"),
            symbol=ASSET_TO_PLOT,
            interval=tf,
            check_date="100 days ago UTC" # A shorter period can be selected for the chart
        )
        df_chart = indicator_calculator.calculate_indicators(historical_data)
        df_chart.index = pd.to_datetime(df_chart.index)
    
    except Exception as e:
        print(f"❌ ERROR: Failed to load chart data: {e}")
        sys.exit()
    
    fig, ax1 = plt.subplots(1, 1, figsize=(18, 10))
    
    # Price and Ichimoku Lines
    ax1.plot(df_chart.index, df_chart['Close'], label='Price', color='black', alpha=0.7)
    ax1.plot(df_chart.index, df_chart['Tenkan-sen'], label='Tenkan (TS)', color='red', linewidth=1)
    ax1.plot(df_chart.index, df_chart['Kijun-sen'], label='Kijun (KS)', color='blue', linewidth=1)
    
    # Cloud (Kumo) Drawing (fill_between)
    ax1.fill_between(df_chart.index, 
                     df_chart['Senkou Span A'], 
                     df_chart['Senkou Span B'], 
                     where=df_chart['Senkou Span A'] >= df_chart['Senkou Span B'],
                     color='green', alpha=0.2, label='Bullish Cloud')
    
    ax1.fill_between(df_chart.index, 
                     df_chart['Senkou Span A'], 
                     df_chart['Senkou Span B'], 
                     where=df_chart['Senkou Span A'] < df_chart['Senkou Span B'],
                     color='red', alpha=0.2, label='Bearish Cloud')
    
    # Chikou Span
    ax1.plot(df_chart.index, df_chart['Chikou Span'], label='Chikou (CS)', color='lime', alpha=0.6, linestyle='--')
    
    # Market Structure Signals (Trend Filter instead of HH/HL/LH/LL)
    # Mark market structure change/trend just above or below price
    uptrend_start = df_chart[df_chart['MARKET_STRUCTURE_TREND'] == 'UPTREND'].index
    downtrend_start = df_chart[df_chart['MARKET_STRUCTURE_TREND'] == 'DOWNTREND'].index
    
    ax1.scatter(uptrend_start, df_chart.loc[uptrend_start, 'Close'] * 0.99, marker='$\u25B2$', # Üçgen
                color='green', s=50, label='Uptrend Start')
    ax1.scatter(downtrend_start, df_chart.loc[downtrend_start, 'Close'] * 1.01, marker='$\u25BC$', # Ters Üçgen
                color='red', s=50, label='Downtrend Start')
        
    ax1.set_title(f'Test Case 2: Ichimoku Custom Rule ({ASSET_TO_PLOT} {tf})', fontsize=16)
    ax1.set_ylabel('Price (USD)')
    ax1.legend(loc='upper right')
    ax1.grid(True, alpha=0.3)
    plt.show()
    print(f"✅ {ASSET_TO_PLOT} chart created successfully.\n")

plot_ichimoku_with_signal('BTCUSDT', best_combo_btc['Timeframe'])
plot_ichimoku_with_signal('ETHUSDT', best_combo_eth['Timeframe'])
# Out:
# ✅ Backtest data loaded: 2400 rows from 100 days ago UTC
# ✅ Indicators calculated successfully. 2298 rows available.
# ✅ BTCUSDT chart created successfully.
#
# ✅ Backtest data loaded: 2400 rows from 100 days ago UTC
# ✅ Indicators calculated successfully. 2298 rows available.
# ✅ ETHUSDT chart created successfully.

# %%
# COMPARISON OF CASE 1 AND 2

# Case 1 Loading Grid Results
try:
    GRID_RESULTS_DF = pd.read_csv("case1_grid_search_results.csv")
    GRID_RESULTS_DF['Strategy_Type'] = 'Grid (C1)'
except FileNotFoundError:
    print("❌ ERROR: Grid Search results ('case1_grid_search_results.csv') not found.")
    sys.exit()

# Loading Case 2 Custom Results
try:
    CUSTOM_RESULTS_DF = pd.read_csv("case2_ichimoku_results.csv")
    CUSTOM_RESULTS_DF['Strategy_Type'] = 'Ichimoku (C2)'
except FileNotFoundError:
    print("❌ ERROR: Ichimoku Custom Rule results ('case2_ichimoku_results.csv') not found.")
    sys.exit()

# Find the best PnL for each asset/TF in the Grid
best_grid = GRID_RESULTS_DF.loc[GRID_RESULTS_DF.groupby(['Asset', 'Timeframe'])['Total_PnL_USD'].idxmax()]

# Combine with Custom Rule (Custom is already just 1 rule)
comparison_df = pd.concat([best_grid, CUSTOM_RESULTS_DF])


print("="*80)
print("COMPARISON: BEST GRID (C1) vs ICHIMOKU (C2)")
print("="*80)

for asset in ["BTCUSDT", "ETHUSDT"]:
    print(f"\n--- 📈 {asset} COMPARISON RESULTS ---")
    
    asset_comparison = comparison_df[comparison_df['Asset'] == asset].sort_values(
        by=['Timeframe', 'Total_PnL_USD'], ascending=[True, False]
    )
    
    # Overall ranking by PnL
    final_view = asset_comparison.sort_values(by='Total_PnL_USD', ascending=False)
    print(final_view.to_markdown(index=False))
# Out:
# ================================================================================
# COMPARISON: BEST GRID (C1) vs ICHIMOKU (C2)
# ================================================================================
#
# --- 📈 BTCUSDT COMPARISON RESULTS ---
# | Asset   | Timeframe   | Entry_Rule    | Exit_Rule     |   Total_PnL_USD |   Win_Rate |   Completed_Trades | Strategy_Type   |
# |:--------|:------------|:--------------|:--------------|----------------:|-----------:|-------------------:|:----------------|
# | BTCUSDT | 4h          | RSI_25        | ST_BUY        |         16114.8 |        100 |                 22 | Grid (C1)       |
# | BTCUSDT | 1h          | RSI_40        | ST_BUY        |         11858.1 |        100 |                 92 | Grid (C1)       |
# | BTCUSDT | 1d          | RSI_40        | ST_BUY        |         10213   |        100 |                 15 | Grid (C1)       |
# | BTCUSDT | 1d          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |
# | BTCUSDT | 1h          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |
# | BTCUSDT | 4h          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |
#
# --- 📈 ETHUSDT COMPARISON RESULTS ---
# | Asset   | Timeframe   | Entry_Rule    | Exit_Rule     |   Total_PnL_USD |   Win_Rate |   Completed_Trades | Strategy_Type   |
# |:--------|:------------|:--------------|:--------------|----------------:|-----------:|-------------------:|:----------------|
# | ETHUSDT | 4h          | RSI_25        | BB_B_0.40     |         19702.9 |        100 |                 26 | Grid (C1)       |
# | ETHUSDT | 1d          | RSI_40        | BB_B_0.35     |         17459.7 |        100 |                 21 | Grid (C1)       |
# | ETHUSDT | 1h          | RSI_20        | RSI_60        |          4676.3 |        100 |                 25 | Grid (C1)       |
# | ETHUSDT | 1d          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |
# | ETHUSDT | 1h          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |
# | ETHUSDT | 4h          | IchimokuEntry | CustomExit/SL |             0   |          0 |                  0 | Ichimoku (C2)   |

# %%
"""
    CASE 3
"""
# Out:
# '\n    CASE 3\n'

# %%
#APPLYYING THE BEST ENTRY & EXIT COMBO FROM CASE 1 & 2 TO OCT-NOV 2025

from typing import List, Dict, Any
FORWARD_TEST_STRATEGIES: List[Dict[str, Any]] = []

for asset in ["BTCUSDT", "ETHUSDT"]:
    # Compare all results (Best of Grid + Custom Rule) by asset
    best_overall_combo = comparison_df[comparison_df['Asset'] == asset].sort_values(
        by='Total_PnL_USD', ascending=False
    ).iloc[0]
    
    FORWARD_TEST_STRATEGIES.append({
        'Asset': best_overall_combo['Asset'],
        'TF': best_overall_combo['Timeframe'],
        'Type': best_overall_combo['Strategy_Type'],
        'Entry': best_overall_combo['Entry_Rule'],
        'Exit': best_overall_combo['Exit_Rule']
    })

print("✅ Strategies for Forward Testing Have Been Determined.")
print("--------------------------------------------------")
for s in FORWARD_TEST_STRATEGIES:
    print(f"[{s['Asset']}] Best Strategy: {s['Type']} ({s['TF']}) (Entry: {s['Entry']}) (Exit: {s['Exit']})")
print("--------------------------------------------------")


# STRUCTURE
load_dotenv()
data_loader = DataLoader()
indicator_calculator = IndicatorCalculator()

FORWARD_TEST_START_DATE = "1 Oct, 2025" 
CASE3_LOG_FILE = "case3_forward_test_log.txt"
forward_logger = LoggingObserver(log_file=CASE3_LOG_FILE)

FORWARD_RESULTS_DF = pd.DataFrame(columns=[
    'Asset', 'Timeframe', 'Entry_Rule', 'Exit_Rule', 'Strategy_Type',
    'Total_PnL_USD', 'Win_Rate', 'Completed_Trades'
])


# FORWARD TEST CYCLE
for strategy_info in FORWARD_TEST_STRATEGIES:
    asset = strategy_info['Asset']
    tf = strategy_info['TF']
    strat_type = strategy_info['Type']
    entry_id = strategy_info['Entry']
    exit_id = strategy_info['Exit']
    
    print(f"\n--- 📥 {strat_type} Verisi Çekiliyor: {asset} / {tf} ---")
    
    # Fetch Data and Calculate Indicators
    try:
        historical_data = data_loader.download_crypto_data_interval_backtest(
            api_key=os.getenv("BINANCE_API_KEY"),
            api_secret=os.getenv("BINANCE_API_SECRET"),
            symbol=asset,
            interval=tf,
            check_date=FORWARD_TEST_START_DATE 
        )
        df_processed = indicator_calculator.calculate_indicators(historical_data)
        
        if df_processed.empty:
            print(f"⚠️ {asset}/{tf} no Valid data. Skipping.")
            continue
            
    except Exception as e:
        print(f"❌ERROR: Data extraction/processing error: {e}. Skipping.")
        continue


    print(f"   Testing: {strat_type}...")
    
    # Prepare strategy (Grid or Ichimoku)
    if 'Grid' in strat_type:
        current_strategy = GridSearchStrategy(entry_id, exit_id, stop_loss=0.02)
    else: # Ichimoku
        current_strategy = IchimokuCustomStrategy(stop_loss=0.02)

    # Prepare and Run the Bot
    bot = TradingBot(coin_symbol=asset)
    bot.set_strategy(current_strategy)
    bot.register_observer(forward_logger) 

    final_balance = bot.backtest_trading(
        initial_balance=10000,
        stop_loss=0.02,
        df_with_indicators=df_processed,
        position_size_pct=1.0
    )

    pnl = final_balance - 10000
    stats = bot.get_trade_statistics()

    new_row = {
        'Asset': asset,
        'Timeframe': tf,
        'Entry_Rule': entry_id, 
        'Exit_Rule': exit_id,
        'Strategy_Type': strat_type,
        'Total_PnL_USD': round(pnl, 2),
        'Win_Rate': round(stats['win_rate'], 4),
        'Completed_Trades': stats['completed_trades']
    }

    FORWARD_RESULTS_DF.loc[len(FORWARD_RESULTS_DF)] = new_row


FORWARD_RESULTS_FILE = "case3_forward_test_results.csv"
FORWARD_RESULTS_DF.to_csv(FORWARD_RESULTS_FILE, index=False)

print("✅ TEST CASE 3: FORWARD TEST SUMMARY")
print(FORWARD_RESULTS_DF.to_markdown(index=False))
print("="*70)
print(f"💾 Results Saved: {FORWARD_RESULTS_FILE}")
# Out:
# ✅ Strategies for Forward Testing Have Been Determined.
# --------------------------------------------------
# [BTCUSDT] En İyi Strateji: Grid (C1) (4h) (Entry: RSI_25) (Exit: ST_BUY)
# [ETHUSDT] En İyi Strateji: Grid (C1) (4h) (Entry: RSI_25) (Exit: BB_B_0.40)
# --------------------------------------------------
# [LOG] LoggingObserver initialized - Log target: case3_forward_test_log.txt
#
# --- 📥 Grid (C1) Verisi Çekiliyor: BTCUSDT / 4h ---
# ✅ Backtest data loaded: 371 rows from 1 Oct, 2025
# ✅ Indicators calculated successfully. 269 rows available.
#    Testing: Grid (C1)...
# 🤖 TradingBot initialized for BTCUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for BTCUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 269 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 0.13407183641244824 adet BTCUSDT $84532.01 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $11333.36
#    Profit/Loss: $1333.36 (13.33%)
#
# ======================================================================
#
#
# --- 📥 Grid (C1) Verisi Çekiliyor: ETHUSDT / 4h ---
# ✅ Backtest data loaded: 371 rows from 1 Oct, 2025
# ✅ Indicators calculated successfully. 269 rows available.
#    Testing: Grid (C1)...
# 🤖 TradingBot initialized for ETHUSDT
# ✅ Observer registered: LoggingObserver
#
# 🔙 Starting BACKTEST for ETHUSDT
#    Initial Balance: $10000.00
#    Position Size: 100.0%
# 📊 Processing 269 candles...
# ℹ️ Backtest sonu: Kalan pozisyon 3.9785320819366903 adet ETHUSDT $2730.8 fiyattan satıldı.
#
# 📊 Backtest Complete!
#    Final Balance: $10864.58
#    Profit/Loss: $864.58 (8.65%)
#
# ======================================================================
#
# ✅ TEST CASE 3: FORWARD TEST SUMMARY
# | Asset   | Timeframe   | Entry_Rule   | Exit_Rule   | Strategy_Type   |   Total_PnL_USD |   Win_Rate |   Completed_Trades |
# |:--------|:------------|:-------------|:------------|:----------------|----------------:|-----------:|-------------------:|
# | BTCUSDT | 4h          | RSI_25       | ST_BUY      | Grid (C1)       |         1333.36 |        100 |                  2 |
# | ETHUSDT | 4h          | RSI_25       | BB_B_0.40   | Grid (C1)       |          864.58 |        100 |                  2 |
# ======================================================================
# 💾 Results Saved: case3_forward_test_results.csv
